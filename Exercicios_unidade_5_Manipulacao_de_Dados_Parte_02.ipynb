# %% [markdown]
# ![](https://i.imgur.com/JsMvGnP.png)

# %% [markdown]
# ## Exercícios de manipulação de dados - Parte 2

# %% [markdown]
# Neste Jupyter notebook você irá resolver uma lista de exercícios utilizando a linguagem Python e a biblioteca Pandas.
#
# Todos os datasets utilizados nos exercícios estão salvos na pasta **datasets**.
#
# Todo o seu código deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.

# %% [markdown]
# ### Tarefa 1. Importe o dataset e salve os dados em um dataframe
#
# Os dados estão salvos no arquivo ***datasets/US_Crime_Rates_1960_2014.csv***.
#
# Este dataset contém dados de crimes ocorridos nos Estados Unidos no período de 1960 até 2014.
#
# Salve os dados em uma variável de nome *crime*.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import datetime

# %%
crime = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pandas_atividades/US_Crime_Rates_1960_2014.csv')

# %% [markdown]
# ### Tarefa 2. Qual o tipo de dados em cada coluna?

# %%
#utilizar .dtypes

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ### Tarefa 3. Converta o tipo de dado da coluna Year para o tipo datetime
#
# *Dica: procure na documentação da biblioteca como fazer tal conversão*

# %%
crime.head()
# Out:
#    Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  1960   179323175  3384200  ...    912100        1855400         328200
# 1  1961   182992000  3488000  ...    949600        1913000         336000
# 2  1962   185771000  3752200  ...    994300        2089600         366800
# 3  1963   188483000  4109500  ...   1086400        2297800         408300
# 4  1964   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %%
# Seu código

# %%
crime['Year'] = pd.to_datetime(crime['Year'], format='%Y')

# %%
crime.head()
# Out:
#         Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0 1960-01-01   179323175  3384200  ...    912100        1855400         328200
# 1 1961-01-01   182992000  3488000  ...    949600        1913000         336000
# 2 1962-01-01   185771000  3752200  ...    994300        2089600         366800
# 3 1963-01-01   188483000  4109500  ...   1086400        2297800         408300
# 4 1964-01-01   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %%
crime['Year'] = pd.to_datetime(crime['Year'])

# %%
crime.head()
# Out:
#         Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0 1960-01-01   179323175  3384200  ...    912100        1855400         328200
# 1 1961-01-01   182992000  3488000  ...    949600        1913000         336000
# 2 1962-01-01   185771000  3752200  ...    994300        2089600         366800
# 3 1963-01-01   188483000  4109500  ...   1086400        2297800         408300
# 4 1964-01-01   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Tarefa 4. Configure a coluna Year como index do DataFrame.
#
# *Dica: use a função set_index() do Pandas*

# %%
# df.set_index('nome da coluna')

# %%
crime_index = crime.set_index('Year')

# %% [markdown]
# ### Tarefa 5. Remova a coluna Total do DataFrame.

# %%
# df.drop(columns = ['nome da coluna'])

# %%
crime_2 = crime.drop(columns=['Total'])

# %% [markdown]
# ### Tarefa 6. Encontre o número de roubos de carro do ano de 1978.

# %%
# Seu código (1288674)

# %%
crime_2.query('Year == 1978').head()
# Out:
#          Year  Population  Violent  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 18 1978-01-01   218059000  1085550  ...   3128300        5991000        1004100
#
# [1 rows x 11 columns]

# %%
valor = crime_2.loc[18, 'Vehicle_Theft']

# %%
print(f'O ano de 1978 teve {valor} carros roubados')
# Out:
# O ano de 1978 teve 1004100 carros roubados

# %% [markdown]
# ### Tarefa 7. Retorne a linha do ano em que houve o maior número de assasinatos.
#
# *Dica: use a coluna Murder como referência.*

# %%
# Seu código

# %%
#maior numero de assassinatos:
crime['Murder'].max()

# %%
#retornar a linha correspondente a murder == 24700

# %%
crime.loc[crime['Murder']==24700]

# %% [markdown]
# ### Tarefa 8. Retorne o número de assassinatos do ano em que foi registrado o menor número de roubo de carros.

# %%
# Seu código

# %%
#menor numero de roubo de carro:
crime['Vehicle_Theft'].min()

# %%
#achar ano correspondente a menor roubos de carro:
crime.loc[crime['Vehicle_Theft']==328200]

# %%
#achar numero de assassinatos do ano

# %%
crime.iloc[[0], 11]

# %% [markdown]
# **Parabéns! Você chegou ao fim**
